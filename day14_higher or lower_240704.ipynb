# %%
#day14 Higher or Lower
#tip1. Breakdown the Problem
#tip2. make a to-do list
#tip3. Turn the problem into comment
#tip4. Write code > run code > fix code > Write code

# %%
# flowchar of the project _higher and lower
from PIL import Image
from IPython.display import display
img = Image.open('day14_flowchart.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=398x952>

# %%
# higher_lower game _ver1.1
import random
from art import logo, vs
from game_data import data
print(logo)
score = 0

first_person = data[random.randint(1,len(data))-1]
# print(first_person)

def selecting_different_people(first_p):
    second_p = data[random.randint(1,len(data))-1]
    while (first_p == second_p) or (first_p["follower_count"] == second_p["follower_count"]):
        second_p = data[random.randint(1,len(data))-1]
    return second_p
# print(selecting_different_people(first_person))

def comment_of_people(first_p, second_p):
    print(f"Compare A: {first_p['name']}, {first_p['description']}, from {first_p['country']}.")
    print(vs)
    print(f"Against B: {second_p['name']}, {second_p['description']}, from {second_p['country']}.")
# SyntaxError: f-string: unmatched '['
# problem: double quotes inside double quotes. from https://stackoverflow.com/questions/67540413/f-string-unmatched-in-line-with-function-call
# solution: print(f"I know {data[0]['name']}")

def follower_comparing(first_p, second_p):
    if first_p["follower_count"] > second_p["follower_count"]:
        return first_p
    else:
        return second_p

should_continue = True
while should_continue:
    second_person = selecting_different_people(first_person)
    comment_of_people(first_person, second_person)
    answer = follower_comparing(first_person, second_person)
    print(f"Pssss, answer: {answer['name']}")
    choice = input("Who has more followers? Type 'A' or 'B': ")
    if choice == "A":
        choice = first_person
    else:
        choice = second_person
    
    # checking the answer and choice
    if answer == choice:
        score +=1
        print(f"You're right! Current score: {score}.\n")
    else:
        should_continue = False

print(f"Sorry, thats' wrong. Final score: {score}")
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Gigi Hadid, Model, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Kendall Jenner, Reality TV personality and Model, from United States.
# Pssss, answer: Kendall Jenner
# Who has more followers? Type 'A' or 'B':  B
# You're right! Current score: 1.
#
# Compare A: Gigi Hadid, Model, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Ellen DeGeneres, Comedian, from United States.
# Pssss, answer: Ellen DeGeneres
# Who has more followers? Type 'A' or 'B':  B
# You're right! Current score: 2.
#
# Compare A: Gigi Hadid, Model, from United States.
#
#  _    __
# | |  / /____
# ...

# %%
# higher_lower game _ver1.0
import random
from art import logo
from art import vs
print(logo)
score = 0

first_person = data[random.randint(1,len(data))-1]
# print(first_person)

def selecting_different_people(first_p):
    same = True
    while same:
        second_p = data[random.randint(1,len(data))-1]
        if (first_p != second_p) and first_p["follower_count"] != second_p["follower_count"]:
            same = False
    return second_p
# print(selecting_different_people(first_person))

def comment_of_people(first_p, second_p):
    print(f"Compare A: {first_p['name']}, {first_p['description']}, from {first_p['country']}.")
    print(vs)
    print(f"Against B: {second_p['name']}, {second_p['description']}, from {second_p['country']}.")
# SyntaxError: f-string: unmatched '['
# problem: double quotes inside double quotes. from https://stackoverflow.com/questions/67540413/f-string-unmatched-in-line-with-function-call
# solution: print(f"I know {data[0]['name']}")

def follower_comparing(first_p, second_p):
    if first_p["follower_count"] > second_p["follower_count"]:
        return first_p
    else:
        return second_p

should_continue = True
while should_continue:
    second_person = selecting_different_people(first_person)
    comment_of_people(first_person, second_person)
    answer = follower_comparing(first_person, second_person)
    print(f"Pssss, answer: {answer['name']}")
    choice = input("Who has more followers? Type 'A' or 'B': ")
    if choice == "A":
        choice = first_person
    else:
        choice = second_person
    
    # checking the answer and choice
    if answer == choice:
        score +=1
        print(f"You're right! Current score: {score}.\n")
    else:
        should_continue = False

print(f"Sorry, thats' wrong. Final score: {score}")
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Gigi Hadid, Model, from United States.
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Real Madrid CF, Football club, from Spain.
# Pssss, answer: Real Madrid CF
# Who has more followers? Type 'A' or 'B':  A
# Sorry, thats' wrong. Final score: 0

# %%
# higher and lower game _teacher solution
import random

from replit import clear

from art import logo, vs
#from game_data import data

def get_random_account():
    """Get data from random account"""
    return random.choice(data)

def format_data(account):
    """Format account into printable format: name, description and country"""
    name = account["name"]
    description = account["description"]
    country = account["country"]
    return f"{name}, a {description}, from {country}."

def check_answer(guess, a_followers, b_followers):
    """Checks followers against user's guess and returns True if they got if right. Or False if they got it wrong."""
    if a_followers > b_followers:
        return guess == "a"
    else:
        return guess == "b"

def game():
    print(logo)
    score = 0
    game_should_continue = True
    account_a = get_random_account()
    account_b = get_random_account()

    while game_should_continue:
        account_a = account_b
        account_b = get_random_account()

        while account_a == account_b:
            account_b = get_random_account()

        print(f"Compare A: {format_data(account_a)}.")
        print(vs)
        print(f"Against B: {format_data(account_b)}.")

        guess = input("Who has more followers? Type 'A' or 'B': ").lower()
        a_follower_count = account_a["follower_count"]
        b_follower_count = account_b["follower_count"]
        is_correct = check_answer(guess, a_follower_count, b_follower_count)

        clear()
        print(logo)
        if is_correct:
            score +=1
            print(f"You are right! Current score: {score}")
        else:
            game_should_continue = False
            print(f"Sorry, that's wrong. Fianl score: {score}")
game()

# reflection: I could call the 'data' variable form the .py file.
# I could make simple selecting_different_people(first_p) function refer to teacher's code
# I could call many vairalbes from one file in a line
# It was good to set the functions properly
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Victoria's Secret, a Lingerie brand, from United States..
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Ronaldinho, a Footballer, from Brasil..
# Who has more followers? Type 'A' or 'B':  A
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# You are right! Current score: 1
# Compare A: Ronaldinho, a Footballer, from Brasil..
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# ...
