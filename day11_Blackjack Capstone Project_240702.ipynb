# %%
# day11_Blackjack Capstone Project
############### Our Blackjack House Rules #####################

## The deck is unlimited in size. 
## There are no jokers. 
## The Jack/Queen/King all count as 10.
## The the Ace can count as 11 or 1.
## Use the following list as the deck of cards:
## cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
## The cards in the list have equal probability of being drawn.
## Cards are not removed from the deck as they are drawn.
## The computer is the dealer.

# %%
# flowchar of the project
from PIL import Image
from IPython.display import display
img = Image.open('day11_flowchart.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=698x942>

# %%
# day11_Blackjack Capstone Project
#import logo from art
import random
from art import logo 

def card_allocate(cards):
    allocated_card= random.choice(cards)
    full_cards.remove(allocated_card)
    return allocated_card

def get_more_card(card_list, cards):
    additional_card = random.choice(cards)
    card_list.append(additional_card)

def showing_result(list1, dealer_card):
    print(f"  Your cards: {list1}, current score: {sum(list1)}")
    print(f"  Dealer's first card: {dealer_card}")

def showing_finial_fesult(list1, list2):
    print(f"  Your final hand: {list1}, current score: {sum(list1)}")
    print(f"  Dealer's final hand: {list2}, final score: {sum(list2)}")

should_continue = input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
while should_continue == "y":
    # cards allocation
    print(logo)
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    full_cards = cards + cards + cards + cards
    
    my_card1 = card_allocate(full_cards)
    my_card2 = card_allocate(full_cards)
    my_card_list = [my_card1, my_card2]
    
    dealer_card1 = card_allocate(full_cards)
    dealer_card2 = card_allocate(full_cards)
    dealer_card_list = [dealer_card1, dealer_card2]
    
    showing_result(my_card_list, dealer_card1)
    
    # getting card
    if sum(my_card_list) == 21:
        print("Blackjack! You win!")
    else:
        get_again = True
        while get_again:
            one_more_card = input("Type 'y' to get another card, type 'n' to pass: ")
            if one_more_card == "y":
                get_more_card(my_card_list, full_cards)
                showing_result(my_card_list, dealer_card1)
                if sum(my_card_list) > 21:
                    showing_finial_fesult(my_card_list, dealer_card_list)
                    print("You went over. You lose")
                    get_again = False
            else:
                get_again = False
    
    # comparing with dealers card
    if sum(my_card_list) < 21:
        print(f"  Your cards: {my_card_list}, current score: {sum(my_card_list)}")
        print(f"  Dealer's cards: {dealer_card_list}, current score: {sum(dealer_card_list)}")
        while (sum(dealer_card_list)<= 16):
            print("  Dealer get one more card because it is under 17.")
            get_more_card(dealer_card_list, full_cards)
            print(f"  Your cards: {my_card_list}, current score: {sum(my_card_list)}")
            print(f"  Dealer's cards: {dealer_card_list}, current score: {sum(dealer_card_list)}")
        if sum(dealer_card_list) > 21:
            showing_finial_fesult(my_card_list, dealer_card_list)
            print("You win!")
        elif sum(dealer_card_list) > sum(my_card_list):
            showing_finial_fesult(my_card_list, dealer_card_list)
            print("You Lose...")
        elif sum(dealer_card_list) < sum(my_card_list):
            showing_finial_fesult(my_card_list, dealer_card_list)
            print("You win!")
        else: # sum(dealer_card_list) == sum(my_card_list)
            if len(dealer_card_list) > len(my_card_list):
                showing_finial_fesult(my_card_list, dealer_card_list)
                print("You win!")
            elif len(dealer_card_list) < len(my_card_list):
                showing_finial_fesult(my_card_list, dealer_card_list)
                print("You Lose...")
            else: # len(dealer_card_list) == len(my_card_list)
                showing_finial_fesult(my_card_list, dealer_card_list)
                print("Draw") 
    should_continue = input("Do you want to play a game of Blackjack again? Type 'y' or 'n': ")

print("The game is over.")
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#   Your cards: [10, 5], current score: 15
#   Dealer's first card: 4
# Type 'y' to get another card, type 'n' to pass:  n
#   Your cards: [10, 5], current score: 15
#   Dealer's cards: [4, 7], current score: 11
#   Dealer get one more card because it is under 17.
#   Your cards: [10, 5], current score: 15
#   Dealer's cards: [4, 7, 8], current score: 19
#   Your final hand: [10, 5], current score: 15
# ...

# %%
# day11_Blackjack Capstone Project _teacher solution
############### Our Blackjack House Rules #####################

## The deck is unlimited in size. 
## There are no jokers. 
## The Jack/Queen/King all count as 10.
## The the Ace can count as 11 or 1.
## Use the following list as the deck of cards:
## cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
## The cards in the list have equal probability of being drawn.
## Cards are not removed from the deck as they are drawn.

import random
from replit import clear
from art import logo

def deal_card():
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    card = random.choice(cards)
    return card

def calculate_score(cards):
    if sum(cards) == 21 and len(cards) == 2:
        return 0
    if 11 in cards and sum(cards) > 21:
        cards.remove(11)
        cards.append(1)
    return sum(cards)

def compare(user_score, computer_score):
    if user_score > 21 and computer_score > 21:
        return "You went over. You lose"
    if user_score == computer_score:
        return "Draw"
    elif computer_score == 0:
        return "Lose, opponent has Blackjack"
    elif user_score == 0 :
        return "Win with a Blackjack"
    elif user_score > 21:
        return "You went over. You lose"
    elif computer_score > 21:
        return "Opponent went over. You win"
    elif user_score > computer_score:
        return "You win"
    else:
        return "You lose"

def play_game():
    print(logo)
    user_cards = []
    computer_cards = []
    is_game_over = False
    for k in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())
    while not is_game_over:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)
        print(f"  Your cards; {user_cards}, current score: {user_score}")
        print(f"  Computer's first card: {computer_cards[0]}")

        if user_score == 0 or computer_score == 0 or user_score > 21:
            is_game_over = True
        else:
            user_should_deal = input("Type 'y' to get another card, type 'n' to pass: ")
            if user_should_deal == "y":
                user_cards.append(deal_card())
            else:
                is_game_over = True
    while computer_score != 0 and computer_score < 17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)

        print(f"  Your final hand: {user_cards}, final score: {user_score}")
        print(f"  Computer's final hand: {computer_cards}, final score: {computer_score}")
        print(compare(user_score, computer_score))

while input("Do you want to play a game of Blackjack? Type 'y' or 'n': ") == "y":
    clear()
    play_game()

# reflection: it was good to think about the limitation of the cards
# the special case for 'A' must be regared in my code too.
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#   Your cards; [8, 7], current score: 15
#   Computer's first card: 10
# Type 'y' to get another card, type 'n' to pass:  y
#   Your cards; [8, 7, 7], current score: 22
#   Computer's first card: 10
#   Your final hand: [8, 7, 7], final score: 22
#   Computer's final hand: [10, 3, 8], final score: 21
# You went over. You lose
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
# .------.            _     _            _    _            _
# ...

# %%
# day11_Blackjack Capstone Project _ ver1.1
import random
from art import logo 

def card_allocate(cards):
    allocated_card= random.choice(cards)
    full_cards.remove(allocated_card)
    return allocated_card

def get_more_card(card_list, cards):
    additional_card = random.choice(cards)
    card_list.append(additional_card)

def showing_result(list1, dealer_card):
    print(f"  Your cards: {list1}, current score: {sum(list1)}")
    print(f"  Dealer's first card: {dealer_card}")

def showing_finial_fesult(list1, list2):
    print(f"  Your final hand: {list1}, current score: {sum(list1)}")
    print(f"  Dealer's final hand: {list2}, final score: {sum(list2)}")

should_continue = input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
while should_continue == "y":
    # cards allocation
    print(logo)
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    full_cards = cards + cards + cards + cards
    
    my_card1 = card_allocate(full_cards)
    my_card2 = card_allocate(full_cards)
    my_card_list = [my_card1, my_card2]
    
    dealer_card1 = card_allocate(full_cards)
    dealer_card2 = card_allocate(full_cards)
    dealer_card_list = [dealer_card1, dealer_card2]
    
    showing_result(my_card_list, dealer_card1)
    
    # getting card
    if sum(my_card_list) == 21:
        print("Blackjack! You win!")
    else:
        get_again = True
        while get_again:
            one_more_card = input("Type 'y' to get another card, type 'n' to pass: ")
            if one_more_card == "y":
                get_more_card(my_card_list, full_cards)
                showing_result(my_card_list, dealer_card1)
                if 11 in my_card_list and sum(my_card_list) > 21:
                    my_card_list.remove(11)
                    my_card_list.append(1)
                    showing_result(my_card_list, dealer_card1)
                if sum(my_card_list) > 21:
                    showing_finial_fesult(my_card_list, dealer_card_list)
                    print("You went over. You lose")
                    get_again = False
                elif sum(my_card_list) == 21:
                    print("Blackjack! You win!")
                    get_again = False
            else:
                get_again = False
    
    # comparing with dealers card
    if sum(my_card_list) < 21:
        print(f"  Your cards: {my_card_list}, current score: {sum(my_card_list)}")
        print(f"  Dealer's cards: {dealer_card_list}, current score: {sum(dealer_card_list)}")
        while (sum(dealer_card_list)<= 16):
            print("  Dealer get one more card because it is under 17.")
            get_more_card(dealer_card_list, full_cards)
            if 11 in dealer_card_list and sum(dealer_card_list) > 21:
                    dealer_card_list.remove(11)
                    dealer_card_list.append(1)
            print(f"  Your cards: {my_card_list}, current score: {sum(my_card_list)}")
            print(f"  Dealer's cards: {dealer_card_list}, current score: {sum(dealer_card_list)}")
        if sum(dealer_card_list) > 21:
            showing_finial_fesult(my_card_list, dealer_card_list)
            print("You win!")
        elif sum(dealer_card_list) > sum(my_card_list):
            showing_finial_fesult(my_card_list, dealer_card_list)
            print("You Lose...")
        elif sum(dealer_card_list) < sum(my_card_list):
            showing_finial_fesult(my_card_list, dealer_card_list)
            print("You win!")
        else: # sum(dealer_card_list) == sum(my_card_list)
            if len(dealer_card_list) > len(my_card_list):
                showing_finial_fesult(my_card_list, dealer_card_list)
                print("You win!")
            elif len(dealer_card_list) < len(my_card_list):
                showing_finial_fesult(my_card_list, dealer_card_list)
                print("You Lose...")
            else: # len(dealer_card_list) == len(my_card_list)
                showing_finial_fesult(my_card_list, dealer_card_list)
                print("Draw") 
    should_continue = input("Do you want to play a game of Blackjack again? Type 'y' or 'n': ")

print("The game is over.")
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n':  y
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#   Your cards: [10, 8], current score: 18
#   Dealer's first card: 10
# Type 'y' to get another card, type 'n' to pass:  y
#   Your cards: [10, 8, 10], current score: 28
#   Dealer's first card: 10
#   Your final hand: [10, 8, 10], current score: 28
#   Dealer's final hand: [10, 6], final score: 16
# You went over. You lose
# Do you want to play a game of Blackjack again? Type 'y' or 'n':  y
# ...
